# %% [markdown]
# # Brain Network Exploratory Data Analysis (EDA)
#
# This notebook performs a **full exploratory data analysis (EDA)** on the brain network dataset stored in `brain_networks.csv`.
#
# **Goals of this analysis**:
# - **Understand the dataset structure**: rows, columns, metadata (network, node, hemisphere).
# - **Assess data quality**: missing values, ranges, summary statistics.
# - **Explore distributions and relationships**: global value distribution, per-network and per-hemisphere behavior, correlations.
# - **Generate insights for downstream tasks**: feature engineering, anomaly detection, or predictive modeling.
#
# **Notebook roadmap** (matches the numbered print sections):
# - **1. Dataset overview**: basic shape, datatypes, sample rows, `info()` and descriptive stats.
# - **2. Metadata summary**: how columns map to networks, nodes, and hemispheres.
# - **3. Statistical summary**: global distribution (mean, median, spread, quantiles).
# - **4. Missing values**: overall missingness + per-column and per-row statistics.
# - **5. Detailed statistics by group**: aggregated metrics by network and hemisphere.
# - **Visual section**: histograms, boxplots, correlation heatmap, Q-Q plot saved as `network_eda.png`.
#
# Run the notebook from top to bottom to reproduce all results.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO

try:
    from IPython.display import display
except ImportError:
    # Fallback when running outside notebooks.
    def display(x):
        print(x)

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (15, 10)

with open("brain_networks.csv", "r", encoding="utf-8") as f:
    csv_data = f.read()

lines = csv_data.strip().split('\n')

# Parse metadata rows
network_row = lines[0].split(',')[1:]
node_row = lines[1].split(',')[1:]
hemi_row = lines[2].split(',')[1:]

if not (len(network_row) == len(node_row) == len(hemi_row)):
    raise ValueError("Metadata rows have inconsistent column counts.")

data_rows = []
for line in lines[4:]:
    if not line.strip():
        continue
    parts = line.split(',')
    row_id = parts[0]
    values = [float(x) for x in parts[1:] if x != '']
    if len(values) != len(network_row):
        raise ValueError(f"Row {row_id} has {len(values)} values; expected {len(network_row)}.")
    data_rows.append([row_id] + values)

df = pd.DataFrame(data_rows)
df.columns = ['row_id'] + [f'col_{i}' for i in range(len(network_row))]

metadata = pd.DataFrame({
    'column': [f'col_{i}' for i in range(len(network_row))],
    'network': [int(x) for x in network_row],
    'node': [int(x) for x in node_row],
    'hemi': hemi_row
})

print("="*80)
print("EXPLORATORY DATA ANALYSIS - NETWORK NODE DATA")
print("="*80)
# Out:
# ================================================================================
# EXPLORATORY DATA ANALYSIS - NETWORK NODE DATA
# ================================================================================

# %%
print("\n1. DATASET OVERVIEW")
print("-" * 80)
print(f"Number of rows (observations): {len(df)}")
print(f"Number of columns (features): {len(df.columns) - 1}")
print(f"Total data points: {(len(df) * (len(df.columns) - 1))}")
print(f"\nData shape: {df.shape}")
print(f"\nData types:\n{df.dtypes.value_counts()}")

print("\nSample of raw data (first 5 rows):")
display(df.head())

print("\nPandas info():")
df.info()

feature_cols = [c for c in df.columns if c != 'row_id']
print("\nDescriptive statistics for feature columns:")
display(df[feature_cols].describe().T)
# Out:
# 1. DATASET OVERVIEW
# --------------------------------------------------------------------------------
# Number of rows (observations): 920
# Number of columns (features): 62
# Total data points: 57040
#
# Data shape: (920, 63)
#
# Data types:
# float64    62
# object      1
# Name: count, dtype: int64
#
# Sample of raw data (first 5 rows):
#   row_id      col_0      col_1      col_2      col_3      col_4      col_5  \
# 0      0  56.055744  92.031036   3.391576  38.659683  26.203819 -49.715569
# 1      1  55.547253  43.690075 -65.495987 -13.974523 -28.274963 -39.050129
# 2      2  60.997768  63.438793 -51.108582 -13.561346 -18.842947  -1.214659
# 3      3  18.514868  12.657158 -34.576603 -32.665958  -7.420454  17.119448
# 4      4  -2.527392 -63.104668 -13.814151 -15.837989 -45.216927   3.483550
#
#        col_6      col_7      col_8  ...     col_52     col_53      col_54  \
# 0  47.461037  26.746613 -35.898861  ...   0.607904 -70.270546   77.365776
# 1  -1.210660 -19.012897  19.568010  ...  57.495071 -76.393219  127.261360
# 2 -65.575806 -85.777428  19.247454  ...  28.317369   9.063977   45.493263
# 3 -41.800869 -58.610184  32.896915  ...  71.439629  65.842979  -10.697547
# 4 -62.613335 -49.076508  18.396759  ...  95.597565  50.960453  -23.197300
#
#       col_55     col_56     col_57     col_58     col_59      col_60  \
# 0 -21.734550   1.028253   7.791784  68.903725 -10.520872  120.490463
# 1 -13.035799  46.381824 -15.752450  31.000332 -39.607521   24.764011
# 2  26.033442  34.212200   1.326110 -22.580757  12.985169  -75.027451
# 3  55.297466   4.255006  -2.420144  12.098393 -15.819172  -37.361431
# 4  43.067562  52.219875  28.232882 -11.719750   5.453649    5.169828
#
#       col_61
# 0 -39.686432
# 1 -36.771008
# 2   6.434262
# 3  -4.650954
# 4  87.809135
#
# [5 rows x 63 columns]
# Pandas info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 63 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   row_id  920 non-null    object
#  1   col_0   920 non-null    float64
#  2   col_1   920 non-null    float64
#  3   col_2   920 non-null    float64
#  4   col_3   920 non-null    float64
#  5   col_4   920 non-null    float64
#  6   col_5   920 non-null    float64
#  7   col_6   920 non-null    float64
#  8   col_7   920 non-null    float64
#  9   col_8   920 non-null    float64
#  10  col_9   920 non-null    float64
#  11  col_10  920 non-null    float64
#  12  col_11  920 non-null    float64
#  13  col_12  920 non-null    float64
#  14  col_13  920 non-null    float64
#  15  col_14  920 non-null    float64
#  16  col_15  920 non-null    float64
#  17  col_16  920 non-null    float64
#  18  col_17  920 non-null    float64
#  19  col_18  920 non-null    float64
#  20  col_19  920 non-null    float64
#  21  col_20  920 non-null    float64
#  22  col_21  920 non-null    float64
#  23  col_22  920 non-null    float64
#  24  col_23  920 non-null    float64
#  25  col_24  920 non-null    float64
#  26  col_25  920 non-null    float64
#  27  col_26  920 non-null    float64
#  28  col_27  920 non-null    float64
#  29  col_28  920 non-null    float64
#  30  col_29  920 non-null    float64
#  31  col_30  920 non-null    float64
#  32  col_31  920 non-null    float64
#  33  col_32  920 non-null    float64
#  34  col_33  920 non-null    float64
#  35  col_34  920 non-null    float64
#  36  col_35  920 non-null    float64
#  37  col_36  920 non-null    float64
#  38  col_37  920 non-null    float64
#  39  col_38  920 non-null    float64
#  40  col_39  920 non-null    float64
#  41  col_40  920 non-null    float64
#  42  col_41  920 non-null    float64
#  43  col_42  920 non-null    float64
#  44  col_43  920 non-null    float64
#  45  col_44  920 non-null    float64
#  46  col_45  920 non-null    float64
#  47  col_46  920 non-null    float64
#  48  col_47  920 non-null    float64
#  49  col_48  920 non-null    float64
#  50  col_49  920 non-null    float64
#  51  col_50  920 non-null    float64
#  52  col_51  920 non-null    float64
#  53  col_52  920 non-null    float64
#  54  col_53  920 non-null    float64
#  55  col_54  920 non-null    float64
#  56  col_55  920 non-null    float64
#  57  col_56  920 non-null    float64
#  58  col_57  920 non-null    float64
#  59  col_58  920 non-null    float64
#  60  col_59  920 non-null    float64
#  61  col_60  920 non-null    float64
#  62  col_61  920 non-null    float64
# dtypes: float64(62), object(1)
# memory usage: 452.9+ KB
#
# Descriptive statistics for feature columns:
#         count      mean        std         min        25%       50%  \
# col_0   920.0 -0.014230  48.906340 -228.101303 -28.645570  0.795935
# col_1   920.0 -0.024642  53.389574 -203.172806 -33.573225  0.167886
# col_2   920.0  0.005682  39.360122 -122.468544 -26.185023 -0.376553
# col_3   920.0  0.020672  42.467636 -113.232346 -29.356626 -2.223320
# col_4   920.0  0.001268  26.011762  -84.018044 -15.425041 -1.405444
# ...       ...       ...        ...         ...        ...       ...
# col_57  920.0  0.017311  37.445607 -127.963936 -22.758688  0.432651
# col_58  920.0  0.034791  34.598793 -102.006760 -21.322153  0.749948
# col_59  920.0 -0.018506  37.285926 -155.694580 -21.480175  0.637232
# col_60  920.0  0.042048  41.200313 -179.431992 -25.035074  0.947857
# col_61  920.0  0.043531  49.089624 -136.211441 -30.841835 -1.234971
#
#               75%         max
# col_0   29.269680  163.615540
# col_1   34.075309  180.641937
# col_2   23.395318  188.279419
# col_3   24.293522  224.820267
# col_4   15.110825  131.839691
# ...           ...         ...
# col_57  23.335408  146.782150
# col_58  22.755759  120.648735
# col_59  23.083472  142.590225
# col_60  27.797017  120.490463
# col_61  31.702399  155.478546
#
# [62 rows x 8 columns]

# %%
print("\n2. METADATA SUMMARY")
print("-" * 80)
print(f"Unique networks: {metadata['network'].nunique()} - {sorted(metadata['network'].unique())}")
print(f"Unique nodes per network: {metadata.groupby('network')['node'].nunique().to_dict()}")
print(f"Hemispheres: {metadata['hemi'].unique()}")
print(f"Hemisphere distribution: {metadata['hemi'].value_counts().to_dict()}")

print(f"\nNetwork-Node-Hemisphere combinations:")
combo_counts = metadata.groupby(['network', 'node', 'hemi']).size()
print(f"Total combinations: {len(combo_counts)}")
# Out:
# 2. METADATA SUMMARY
# --------------------------------------------------------------------------------
# Unique networks: 17 - [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17)]
# Unique nodes per network: {1: 1, 2: 1, 3: 1, 4: 1, 5: 1, 6: 2, 7: 3, 8: 3, 9: 1, 10: 1, 11: 1, 12: 3, 13: 4, 14: 1, 15: 1, 16: 4, 17: 4}
# Hemispheres: ['lh' 'rh']
# Hemisphere distribution: {'lh': 31, 'rh': 31}
#
# Network-Node-Hemisphere combinations:
# Total combinations: 62

# %%
print("\n3. STATISTICAL SUMMARY")
print("-" * 80)
data_cols = [col for col in df.columns if col != 'row_id']
data_values = df[data_cols].values.flatten()

print(f"Mean: {np.mean(data_values):.4f}")
print(f"Median: {np.median(data_values):.4f}")
print(f"Std Dev: {np.std(data_values):.4f}")
print(f"Min: {np.min(data_values):.4f}")
print(f"Max: {np.max(data_values):.4f}")
print(f"Range: {np.max(data_values) - np.min(data_values):.4f}")
print(f"Q1 (25%): {np.percentile(data_values, 25):.4f}")
print(f"Q3 (75%): {np.percentile(data_values, 75):.4f}")
print(f"IQR: {np.percentile(data_values, 75) - np.percentile(data_values, 25):.4f}")
# Out:
# 3. STATISTICAL SUMMARY
# --------------------------------------------------------------------------------
# Mean: 0.0034
# Median: -0.0808
# Std Dev: 39.1938
# Min: -293.8646
# Max: 243.6874
# Range: 537.5519
# Q1 (25%): -22.9867
# Q3 (75%): 22.7005
# IQR: 45.6872

# %%
print("\n4. MISSING VALUES")
print("-" * 80)
missing = df.isnull().sum().sum()
print(f"Total missing values: {missing}")
print(f"Percentage missing: {(missing / df.size * 100):.2f}%")

missing_per_col = df.isnull().sum()
missing_pct_per_col = df.isnull().mean() * 100

if missing > 0:
    print("\nTop 10 columns by missing values:")
    missing_summary = pd.DataFrame({
        'missing_count': missing_per_col,
        'missing_pct': missing_pct_per_col
    })
    display(missing_summary.sort_values('missing_count', ascending=False).head(10))

    missing_per_row = df.isnull().sum(axis=1)
    print("\nRow-wise missing value statistics:")
    print(f"  Mean missing per row: {missing_per_row.mean():.2f}")
    print(f"  Max missing in a row: {missing_per_row.max()}")
else:
    print("No missing values detected at column level.")

# visualizations
fig = plt.figure(figsize=(18, 12))
# Out:
# 4. MISSING VALUES
# --------------------------------------------------------------------------------
# Total missing values: 0
# Percentage missing: 0.00%
# No missing values detected at column level.

# %%
plt.figure(figsize=(18, 15))
ax1 = plt.subplot(3, 3, 1)
plt.hist(data_values, bins=50, edgecolor='black', alpha=0.7, color='steelblue')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of All Values')
plt.axvline(np.mean(data_values), color='red', linestyle='--', label=f'Mean: {np.mean(data_values):.2f}')
plt.axvline(np.median(data_values), color='green', linestyle='--', label=f'Median: {np.median(data_values):.2f}')
plt.legend()

# %%
ax2 = plt.subplot(3, 3, 2)
plt.boxplot(data_values, vert=True)
plt.ylabel('Value')
plt.title('Box Plot of All Values')
plt.grid(axis='y', alpha=0.3)

# %%
ax3 = plt.subplot(3, 3, 3)
network_data = []
network_labels = []
for net in sorted(metadata['network'].unique()):
    net_cols = metadata[metadata['network'] == net]['column'].tolist()
    net_indices = [i for i, col in enumerate(data_cols) if col in net_cols]
    net_values = df.iloc[:, [i+1 for i in net_indices]].values.flatten()
    network_data.append(net_values)
    network_labels.append(f'Net {net}')

plt.boxplot(network_data, labels=network_labels)
plt.xlabel('Network')
plt.ylabel('Value')
plt.title('Distribution by Network')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
# Out:
# C:\Users\SAUGAT\AppData\Local\Temp\ipykernel_2432\2853419700.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(network_data, labels=network_labels)

# %%
ax4 = plt.subplot(3, 3, 4)
lh_cols = metadata[metadata['hemi'] == 'lh']['column'].tolist()
rh_cols = metadata[metadata['hemi'] == 'rh']['column'].tolist()
lh_indices = [i for i, col in enumerate(data_cols) if col in lh_cols]
rh_indices = [i for i, col in enumerate(data_cols) if col in rh_cols]
lh_values = df.iloc[:, [i+1 for i in lh_indices]].values.flatten()
rh_values = df.iloc[:, [i+1 for i in rh_indices]].values.flatten()

plt.boxplot([lh_values, rh_values], labels=['Left (lh)', 'Right (rh)'])
plt.ylabel('Value')
plt.title('Distribution by Hemisphere')
plt.grid(axis='y', alpha=0.3)
# Out:
# C:\Users\SAUGAT\AppData\Local\Temp\ipykernel_2432\848250721.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([lh_values, rh_values], labels=['Left (lh)', 'Right (rh)'])

# %%
ax5 = plt.subplot(3, 3, 5)
col_means = df[data_cols].mean()
plt.plot(col_means.values, marker='o', markersize=3, linewidth=1)
plt.xlabel('Column Index')
plt.ylabel('Mean Value')
plt.title('Mean Value per Column')
plt.grid(alpha=0.3)

# %%
ax6 = plt.subplot(3, 3, 6)
sample_cols = data_cols[:min(20, len(data_cols))]
corr = df[sample_cols].corr()
sns.heatmap(corr, cmap='coolwarm', center=0, square=True, cbar_kws={'label': 'Correlation'})
plt.title('Correlation Heatmap (First 20 Columns)')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap (First 20 Columns)')

# %%
ax7 = plt.subplot(3, 3, 7)
row_means = df[data_cols].mean(axis=1)
row_stds = df[data_cols].std(axis=1)
plt.scatter(row_means, row_stds, alpha=0.6, s=100)
plt.xlabel('Row Mean')
plt.ylabel('Row Std Dev')
plt.title('Row Statistics: Mean vs Std Dev')
plt.grid(alpha=0.3)

# %%
ax8 = plt.subplot(3, 3, 8)
network_counts = metadata['network'].value_counts().sort_index()
plt.bar(network_counts.index, network_counts.values, color='teal', alpha=0.7, edgecolor='black')
plt.xlabel('Network')
plt.ylabel('Number of Columns')
plt.title('Columns per Network')
plt.grid(axis='y', alpha=0.3)

# %%
ax9 = plt.subplot(3, 3, 9)
from scipy import stats
stats.probplot(data_values, dist="norm", plot=plt)
plt.title('Q-Q Plot (Normal Distribution)')
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig('network_eda.png', dpi=300, bbox_inches='tight')
print("\n" + "="*80)
print("Visualization saved as 'network_eda.png'")
print("="*80)
plt.show()
# Out:
# ================================================================================
# Visualization saved as 'network_eda.png'
# ================================================================================

# %%
print("\n5. DETAILED STATISTICS BY GROUP")
print("-" * 80)


print("\nStatistics by Network:")
for net in sorted(metadata['network'].unique()):
    net_cols = metadata[metadata['network'] == net]['column'].tolist()
    net_indices = [i for i, col in enumerate(data_cols) if col in net_cols]
    net_values = df.iloc[:, [i+1 for i in net_indices]].values.flatten()
    print(f"  Network {net}: Mean={np.mean(net_values):.2f}, Std={np.std(net_values):.2f}, "
          f"Min={np.min(net_values):.2f}, Max={np.max(net_values):.2f}")


print("\nStatistics by Hemisphere:")
print(f"  Left (lh):  Mean={np.mean(lh_values):.2f}, Std={np.std(lh_values):.2f}, "
      f"Min={np.min(lh_values):.2f}, Max={np.max(lh_values):.2f}")
print(f"  Right (rh): Mean={np.mean(rh_values):.2f}, Std={np.std(rh_values):.2f}, "
      f"Min={np.min(rh_values):.2f}, Max={np.max(rh_values):.2f}")

print("\n" + "="*80)
print("ANALYSIS COMPLETE")
print("="*80)
# Out:
# 5. DETAILED STATISTICS BY GROUP
# --------------------------------------------------------------------------------
#
# Statistics by Network:
#   Network 1: Mean=-0.02, Std=51.17, Min=-228.10, Max=180.64
#   Network 2: Mean=0.01, Std=40.92, Min=-122.47, Max=224.82
#   Network 3: Mean=0.00, Std=29.67, Min=-101.69, Max=159.68
#   Network 4: Mean=0.01, Std=28.39, Min=-122.95, Max=130.78
#   Network 5: Mean=-0.01, Std=36.88, Min=-104.83, Max=125.43
#   Network 6: Mean=-0.02, Std=36.73, Min=-118.04, Max=243.69
#   Network 7: Mean=-0.01, Std=41.10, Min=-221.23, Max=223.22
#   Network 8: Mean=0.00, Std=39.28, Min=-293.86, Max=242.91
#   Network 9: Mean=0.01, Std=19.54, Min=-148.38, Max=138.53
#   Network 10: Mean=0.01, Std=16.17, Min=-97.06, Max=53.65
#   Network 11: Mean=0.02, Std=47.28, Min=-215.06, Max=148.33
#   Network 12: Mean=-0.02, Std=39.58, Min=-161.19, Max=227.51
#   Network 13: Mean=0.02, Std=41.45, Min=-178.83, Max=207.68
#   Network 14: Mean=0.01, Std=32.92, Min=-143.55, Max=120.57
#   Network 15: Mean=-0.01, Std=40.76, Min=-167.16, Max=176.20
#   Network 16: Mean=0.01, Std=45.05, Min=-217.65, Max=198.35
#   Network 17: Mean=0.02, Std=38.08, Min=-179.43, Max=155.48
#
# Statistics by Hemisphere:
#   Left (lh):  Mean=0.00, Std=39.28, Min=-293.86, Max=243.69
#   Right (rh): Mean=0.01, Std=39.11, Min=-215.06, Max=227.51
#
# ================================================================================
# ANALYSIS COMPLETE
# ================================================================================

# %% [markdown]
# # Brain Network Exploratory Data Analysis (EDA)
#
# This notebook performs a **full exploratory data analysis (EDA)** on the brain network dataset stored in `brain_networks.csv`.
#
# **Goals of this analysis**:
# - **Understand the dataset structure**: rows, columns, metadata (network, node, hemisphere).
# - **Assess data quality**: missing values, ranges, summary statistics.
# - **Explore distributions and relationships**: global value distribution, per-network and per-hemisphere behavior, correlations.
# - **Generate insights for downstream tasks**: feature engineering, anomaly detection, or predictive modeling.
#
# **Notebook structure** (matching the numbered sections in the prints):
# - **1. Dataset overview**: basic shape, datatypes, sample rows, `info()` and descriptive stats.
# - **2. Metadata summary**: how columns map to networks, nodes, and hemispheres.
# - **3. Statistical summary**: global distribution (mean, median, spread, quantiles).
# - **4. Missing values**: overall missingness + per-column and per-row statistics.
# - **5. Detailed statistics by group**: aggregated metrics by network and hemisphere.
# - **Visual section**: histograms, boxplots, correlation heatmap, Q-Q plot saved as `network_eda.png`.
